# %% [markdown]
# <a href="https://colab.research.google.com/github/coldbilberry/repo-gui/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace (0, 10, 121)
k = 1
k2 = 4
y = k*np.cos(x)
y = k2*np.cos(x)
plt.plot (x, np.cos(x), y)
